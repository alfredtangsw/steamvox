# %% [markdown]
# # Model Validation
#
# I want to check if my model is working well before I proceed with sentiment analysis.
#
# This is an unsupervised model, so I will have to manually sample, label, and verify.

# %%
import bbcode
import re
import string
import spacy
import json

import nltk

import gensim
from gensim.models import LdaMulticore
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models, similarities

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import steamreviews
import datetime

# %%
#initialise model and dataset

#load dataset, which was previously cleaned in Modelling 3rd Run
model2_df = pd.read_csv('./dataframes/model2_df.csv',index_col=0)

#reload model
lda_model = LdaMulticore.load('./models/nouns_only/saved_model/saved.model')
# Out:
# C:\Users\Alfred\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\Users\Alfred\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\Users\Alfred\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
model_topics = lda_model.show_topics(formatted=False)
for line in lda_model.print_topics(num_words=15):
    print(str(line)+'\n')
# Out:
# (0, '0.023*"three_kingdoms" + 0.023*"series" + 0.021*"fan" + 0.020*"diplomacy" + 0.020*"battle" + 0.018*"love" + 0.018*"best_total_war" + 0.017*"campaign" + 0.014*"total_war_games" + 0.014*"fun" + 0.014*"character" + 0.014*"shogun" + 0.014*"play" + 0.011*"title" + 0.009*"gameplay"')
#
# (1, '0.025*"china" + 0.021*"war" + 0.021*"cao_cao" + 0.019*"lu_bu" + 0.016*"liu_bei" + 0.016*"yuan_shao" + 0.014*"army" + 0.011*"character" + 0.011*"man" + 0.010*"emperor" + 0.010*"warlord" + 0.010*"friend" + 0.010*"history" + 0.009*"faction" + 0.009*"sun_jian"')
#
# (2, '0.037*"faction" + 0.027*"army" + 0.024*"diplomacy" + 0.016*"vassal" + 0.015*"war" + 0.014*"player" + 0.013*"people" + 0.012*"way" + 0.011*"city" + 0.011*"problem" + 0.011*"campaign" + 0.010*"option" + 0.009*"spy" + 0.009*"three_kingdoms" + 0.009*"review"')
#
# (3, '0.053*"unit" + 0.035*"battle" + 0.026*"faction" + 0.023*"army" + 0.022*"general" + 0.022*"character" + 0.013*"diplomacy" + 0.013*"campaign" + 0.011*"hero" + 0.010*"building" + 0.010*"duel" + 0.009*"enemy" + 0.007*"way" + 0.007*"map" + 0.007*"combat"')
#
# (4, '0.032*"campaign" + 0.031*"hour" + 0.027*"issue" + 0.022*"battle" + 0.020*"bug" + 0.017*"crash" + 0.017*"multiplayer" + 0.017*"review" + 0.014*"rome" + 0.014*"fix" + 0.013*"play" + 0.013*"patch" + 0.012*"work" + 0.012*"month" + 0.012*"release"')

# %%
model2_df.head()
# Out:
#    timestamp_created                                             review  \
# 0         1562590376  Well for me game still tons of work. i like it...
# 1         1562581870            I pursued Lu Bu. Now I [b]AM[/b] LU BU.
# 2         1562578221  Absolutely great game. \nAll the new diplomacy...
# 3         1562575368  A fine blend of Warhammer I/II: Total War and ...
# 4         1562568222  Innovative Total Game that has lots of persona...
#
#                                        clean_reviews  \
# 0  ['tons', 'work', 'recommend', 'one', 'diplomac...
# 1                ['pursued', 'lu', 'bu', 'lu', 'bu']
# 2  ['absolutely', 'new', 'diplomacy', 'options', ...
# 3  ['fine', 'blend', 'warhammer', 'two', 'total',...
# 4  ['innovative', 'total', 'lots', 'personality',...
#
#                                        3gram_reviews  \
# 0  ['tons', 'work', 'recommend', 'one', 'diplomac...
# 1                      ['pursued', 'lu_bu', 'lu_bu']
# 2  ['absolutely', 'new', 'diplomacy_options', 'de...
# 3  ['fine', 'blend', 'warhammer_two', 'total_war'...
# 4  ['innovative', 'total', 'lots', 'personality',...
#
#                                         3grams_nouns  \
# 0  ['ton', 'diplomacy', 'joke', 'military_access'...
# 1                                 ['lu_bu', 'lu_bu']
# 2  ['diplomacy_options', 'depth', 'unit_variety',...
# 3  ['blend', 'warhammer_two', 'total_war', 'shogu...
# 4  ['personality', 'diplomacy', 'idea', 'combat',...
#
#                                   3grams_nouns_verbs  \
# 0  ['ton', 'work', 'recommend', 'diplomacy', 'jok...
# 1                       ['pursue', 'lu_bu', 'lu_bu']
# 2  ['diplomacy_options', 'depth', 'unit_variety',...
# 3  ['blend', 'warhammer_two', 'total_war', 'shogu...
# 4  ['personality', 'bring', 'diplomacy', 'idea', ...
#
#                                      3grams_nouns_v2  \
# 0  ['ton', 'diplomacy', 'joke', 'military_access'...
# 1                                 ['lu_bu', 'lu_bu']
# 2  ['diplomacy_options', 'depth', 'unit_variety',...
# 3  ['blend', 'warhammer_two', 'shogun_two', 'pro'...
# 4  ['personality', 'diplomacy', 'idea', 'combat',...
#
#                                3grams_nouns_verbs_v2
# 0  ['ton', 'work', 'recommend', 'diplomacy', 'jok...
# 1                       ['pursue', 'lu_bu', 'lu_bu']
# 2  ['diplomacy_options', 'depth', 'unit_variety',...
# 3  ['blend', 'warhammer_two', 'shogun_two', 'come...
# 4  ['personality', 'bring', 'diplomacy', 'idea', ...

# %%
#Turn data from strings back into lists (only for the lists we want to use)
model2_df['clean_reviews'] = model2_df['clean_reviews'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split())
model2_df['3grams_nouns_v2'] = model2_df['3grams_nouns_v2'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split())

# %%
documents = list(model2_df['3grams_nouns_v2'])
dictionary = gensim.corpora.Dictionary(documents)

#IMPORTANT! If you filtered extremes when CREATING the model, you must give it back EXACTLY the same dictionary or else it may not work with lda_model[corpus]!

dictionary_saved = gensim.corpora.Dictionary.load('./models/nouns_only/saved_model/saved.model.id2word') #this dictionary already had filter_extremes() applied during training step 

corpus = [dictionary_saved.doc2bow(text) for text in documents]
# Out:
# C:\Users\Alfred\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
topic_list = lda_model.print_topics(num_topics=5, num_words=15)
for index, i in enumerate(topic_list):
    str1 = str(i[1])
    for c in "0123456789+*\".":
        str1 = str1.replace(c, "")
    str1 = str1.replace("  ", " ")
    print(str1)
# Out:
# three_kingdoms series fan diplomacy battle love best_total_war campaign total_war_games fun character shogun play title gameplay
# china war cao_cao lu_bu liu_bei yuan_shao army character man emperor warlord friend history faction sun_jian
# faction army diplomacy vassal war player people way city problem campaign option spy three_kingdoms review
# unit battle faction army general character diplomacy campaign hero building duel enemy way map combat
# campaign hour issue battle bug crash multiplayer review rome fix play patch work month release

# %%
#credit to https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/ for this cell's code, which I modified to suit my needs

topic_dict = {'0':'Content & Authenticity',
              '1':'Characters',
              '2':'Strategic Gameplay',
              '3':'Tactical Gameplay',
              '4':'UX/UI, Performance, Stability',
             }

#created a dictionary so I can show topic names instead of numbers, without any complicated code

def format_topics_sentences(ldamodel=lda_model, corpus=corpus, documents=documents):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([topic_dict[str(topic_num)], round(prop_topic,4), topic_keywords]), ignore_index=True)   #replaced int(topic_num) with
                
            else:
                break
                
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    orig_contents = pd.Series(model2_df['review'])
    docs = pd.Series(documents)
    sent_topics_df = pd.concat([sent_topics_df,docs, orig_contents], axis=1)
    return(sent_topics_df)

# %%
#generate dataframe
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, documents=documents)

# %%
len(df_dominant_topic)
# Out:
# 3661

# %%
# Format dataframe
df_dominant_topic = df_topic_sents_keywords.reset_index()

df_dominant_topic.columns = ['document_no', 'dominant_topic', 'topic_perc_contrib', 'keywords', 'tokens','original_text']

df_dominant_topic['num_tokens']=df_dominant_topic['tokens'].map(lambda x: len(x))

df_dominant_topic['unique_tokens']=df_dominant_topic['tokens'].map(lambda x: list(set(x)))
df_dominant_topic['num_unique_tokens']=df_dominant_topic['unique_tokens'].map(lambda x: len(x))

df_dominant_topic = df_dominant_topic[['dominant_topic','original_text','topic_perc_contrib','tokens','num_tokens','unique_tokens','num_unique_tokens','keywords']]


# Show dataframe
df_dominant_topic.head(10)
# Out:
#            dominant_topic                                      original_text  \
# 0       Tactical Gameplay  Well for me game still tons of work. i like it...
# 1              Characters            I pursued Lu Bu. Now I [b]AM[/b] LU BU.
# 2  Content & Authenticity  Absolutely great game. \nAll the new diplomacy...
# 3  Content & Authenticity  A fine blend of Warhammer I/II: Total War and ...
# 4  Content & Authenticity  Innovative Total Game that has lots of persona...
# 5  Content & Authenticity  Masterpiece! It is see lots better an improvem...
# 6  Content & Authenticity             Best historical total war title so far
# 7  Content & Authenticity  Absolutely brilliant and beautiful game. A wor...
# 8  Content & Authenticity    This is my favorite Total War since Medieval 2.
# 9  Content & Authenticity  Great entry in the TW series... While combat l...
#
#    topic_perc_contrib                                             tokens  \
# 0              0.4890  [ton, diplomacy, joke, military_access, cao_ca...
# 1              0.7433                                     [lu_bu, lu_bu]
# 2              0.9391  [diplomacy_options, depth, unit_variety, warha...
# 3              0.5642  [blend, warhammer_two, shogun_two, pro, hero, ...
# 4              0.7753  [personality, diplomacy, idea, combat, famous_...
# 5              0.5616  [masterpiece, improvement, quality, design, wo...
# 6              0.7775                           [best_historical, title]
# 7              0.9664  [successor, title, warhammer_two, thrones_brit...
# 8              0.7775                 [favorite_total_war, medieval_two]
# 9              0.9441  [entry, tw, series, combat, variety, warhammer...
#
#    num_tokens                                      unique_tokens  \
# 0          84  [turn, rule, stability, siege, peace, paradox,...
# 1           2                                            [lu_bu]
# 2          10  [total_wars, diplomacy_options, historically_a...
# 3          17  [return, three_kingdoms, arrow, character, por...
# 4          11  [general, paid_dlc, character, famous_characte...
# 5          24  [quality, use, developer, hope, masterpiece, w...
# 6           2                           [title, best_historical]
# 7          21  [title, favorite_total_war, shogun_two, diplom...
# 8           2                 [medieval_two, favorite_total_war]
# 9          11  [variety, title, tw, warhammer_titles, improve...
#
#    num_unique_tokens                                           keywords
# 0                 57  unit, battle, faction, army, general, characte...
# 1                  1  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 2                  9  three_kingdoms, series, fan, diplomacy, battle...
# 3                 17  three_kingdoms, series, fan, diplomacy, battle...
# 4                 11  three_kingdoms, series, fan, diplomacy, battle...
# 5                 23  three_kingdoms, series, fan, diplomacy, battle...
# 6                  2  three_kingdoms, series, fan, diplomacy, battle...
# 7                 20  three_kingdoms, series, fan, diplomacy, battle...
# 8                  2  three_kingdoms, series, fan, diplomacy, battle...
# 9                 11  three_kingdoms, series, fan, diplomacy, battle...

# %%
df_dominant_topic.tail(10)
# Out:
#                      dominant_topic  \
# 3651  UX/UI, Performance, Stability
# 3652         Content & Authenticity
# 3653  UX/UI, Performance, Stability
# 3654         Content & Authenticity
# 3655         Content & Authenticity
# 3656         Content & Authenticity
# 3657  UX/UI, Performance, Stability
# 3658  UX/UI, Performance, Stability
# 3659  UX/UI, Performance, Stability
# 3660         Content & Authenticity
#
#                                           original_text  topic_perc_contrib  \
# 3651  For those of you having issues getting the gam...              0.5871
# 3652  Ya it works now. Thanks I am really enjoying t...              0.6568
# 3653  Could be the best Total War ever. Gorgeous gra...              0.4574
# 3654  Here begins our tale. The empire, long divided...              0.7740
# 3655  Ignore the butthurt fans who don't like easter...              0.8645
# 3656  As a Chinese, tha game is very well. Thank you...              0.5228
# 3657  Well it launched now, first campaign got ruine...              0.9306
# 3658  game simply dose not load on 1st hour release ...              0.7040
# 3659  i haven't even play it but i just to give cred...              0.7797
# 3660     beautiful    a Great addition to the franchise              0.6663
#
#                                                  tokens  num_tokens  \
# 3651  [issue, start, driver, update, gpu, restart, c...          14
# 3652                                            [thank]           1
# 3653  [best_total_war, graphic, battle, experience, ...          17
# 3654                            [empire, divide, 11_10]           3
# 3655                    [fan, theme, hate, coming_soon]           4
# 3656                              [tha, thank_ca, sega]           3
# 3657  [campaign, turn, bug, screen, campaign_map, fo...          13
# 3658                               [load, release_date]           2
# 3659          [credit, developer, effort, tuning, user]           5
# 3660                               [addition_franchise]           1
#
#                                           unique_tokens  num_unique_tokens  \
# 3651  [firewall, gpu, comp, update, legit, piracy, r...                 13
# 3652                                            [thank]                  1
# 3653  [setting, fp, siege, war, mod, steam, best_tot...                 16
# 3654                            [empire, 11_10, divide]                  3
# 3655                    [hate, fan, coming_soon, theme]                  4
# 3656                              [tha, sega, thank_ca]                  3
# 3657  [turn, shit, release, campaign, delay, bug, fo...                 13
# 3658                               [load, release_date]                  2
# 3659          [user, tuning, developer, credit, effort]                  5
# 3660                               [addition_franchise]                  1
#
#                                                keywords
# 3651  campaign, hour, issue, battle, bug, crash, mul...
# 3652  three_kingdoms, series, fan, diplomacy, battle...
# 3653  campaign, hour, issue, battle, bug, crash, mul...
# 3654  three_kingdoms, series, fan, diplomacy, battle...
# 3655  three_kingdoms, series, fan, diplomacy, battle...
# 3656  three_kingdoms, series, fan, diplomacy, battle...
# 3657  campaign, hour, issue, battle, bug, crash, mul...
# 3658  campaign, hour, issue, battle, bug, crash, mul...
# 3659  campaign, hour, issue, battle, bug, crash, mul...
# 3660  three_kingdoms, series, fan, diplomacy, battle...

# %% [markdown]
# ### Topic Misclassification
#
# As this is an unsupervised learning method, the risk of misclassification is quite significant.
#
# A preview of the results seems quite satisfactory, but short documents tend to have their tropics classified incorrectly... and most reviews on Steam are very short (as established in EDA).
#
# This is why I ran the LDA multiple times, looking for clear topic separation in addition to topics coherent to a human user.
#
# It could be worth exploring the rates of misclassifcation associated with the number of tokens present in the document.
#
# Idea:
#     - Get all documents with 5 or fewer tokens
#     - Randomly sample 200 documents from the total of those with 5 or fewer tokens and manually label them as correct or wrong
#     - Get misclassification rates by token count and find a good cutoff
#     - Exclude the group(s) with the highest misclassficiation rates

# %%
check_tokens = df_dominant_topic['num_tokens'].median() #middle point of the token count data will be the cutoff

# %%
# get all documents with num_token equal to median or fewer of the dataset.

tokens_df = df_dominant_topic[df_dominant_topic['num_tokens']<=check_tokens]
tokens_df.head()
# Out:
#             dominant_topic                                      original_text  \
# 1               Characters            I pursued Lu Bu. Now I [b]AM[/b] LU BU.
# 6   Content & Authenticity             Best historical total war title so far
# 8   Content & Authenticity    This is my favorite Total War since Medieval 2.
# 11              Characters                "Warrior Without Equal" all is said
# 13  Content & Authenticity  best total war i playd so far Good Work lads k...
#
#     topic_perc_contrib                              tokens  num_tokens  \
# 1               0.7433                      [lu_bu, lu_bu]           2
# 6               0.7775            [best_historical, title]           2
# 8               0.7775  [favorite_total_war, medieval_two]           2
# 11              0.6084                           [warrior]           1
# 13              0.6664        [best_total_war, playd, lad]           3
#
#                          unique_tokens  num_unique_tokens  \
# 1                              [lu_bu]                  1
# 6             [title, best_historical]                  2
# 8   [medieval_two, favorite_total_war]                  2
# 11                           [warrior]                  1
# 13        [best_total_war, playd, lad]                  3
#
#                                              keywords
# 1   china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 6   three_kingdoms, series, fan, diplomacy, battle...
# 8   three_kingdoms, series, fan, diplomacy, battle...
# 11  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 13  three_kingdoms, series, fan, diplomacy, battle...

# %%
#check class balance
cls_bal = tokens_df['dominant_topic'].value_counts(normalize=True)
print(cls_bal)
# Out:
# Content & Authenticity           0.698602
# Characters                       0.118591
# UX/UI, Performance, Stability    0.076126
# Strategic Gameplay               0.059037
# Tactical Gameplay                0.047644
# Name: dominant_topic, dtype: float64

# %%
cls_bal.values
# Out:
# array([0.69860176, 0.1185914 , 0.07612636, 0.05903677, 0.04764371])

# %%
#There appears to be significant class imbalance. However, this isn't necessarily due to misclassification. 
#Most reviews are expected to talk about how a game lives up to the series it is from.
#will sample assuming equal probability first, seeing as the topics are not all confirmed to be correctly classified.

sample_tokens_df = tokens_df.sample(frac=0.1,random_state=1337) #take 10% of the data and sample it (according to http://www.raosoft.com/samplesize.html, 193 samples give ~7% margin of error)
sample_tokens_df.head()
# Out:
# Sample size (float): 0.09994821336095287
#               dominant_topic  \
# 638   Content & Authenticity
# 1460  Content & Authenticity
# 1844              Characters
# 382   Content & Authenticity
# 111   Content & Authenticity
#
#                                           original_text  topic_perc_contrib  \
# 638          One of the best entries in this franchise!              0.6663
# 1460  Great game with alot of new features but it la...              0.8881
# 1844  can rule china buy trading rice.\n\nBroken Mar...              0.8457
# 382                 Absolute blast,\nBest TW ive played              0.8330
# 111   really good. everything you want in a total wa...              0.6664
#
#                                            tokens  num_tokens  \
# 638                            [one_best_entries]           1
# 1460  [alot, new_features, design, romance, hero]           5
# 1844        [rule_china, trading, rice, marriage]           4
# 382                  [blast, best_tw, ive_played]           3
# 111                                    [wait_dlc]           1
#
#                                     unique_tokens  num_unique_tokens  \
# 638                            [one_best_entries]                  1
# 1460  [hero, design, alot, romance, new_features]                  5
# 1844        [trading, rule_china, rice, marriage]                  4
# 382                  [blast, ive_played, best_tw]                  3
# 111                                    [wait_dlc]                  1
#
#                                                keywords
# 638   three_kingdoms, series, fan, diplomacy, battle...
# 1460  three_kingdoms, series, fan, diplomacy, battle...
# 1844  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 382   three_kingdoms, series, fan, diplomacy, battle...
# 111   three_kingdoms, series, fan, diplomacy, battle...

# %%
sample_tokens_df.to_csv('./dataframes/sample_tokens_df.csv')

# %%
#manually label sampling dataframe, then import back in

sample_token_mod_df = pd.read_csv('./dataframes/sample_tokens_df_mod.csv',index_col=0)

# %%
sample_token_mod_df.head()
# Out:
#               dominant_topic  \
# 638   Content & Authenticity
# 1460  Content & Authenticity
# 1844              Characters
# 382   Content & Authenticity
# 111   Content & Authenticity
#
#                                           original_text  topic_perc_contrib  \
# 638          One of the best entries in this franchise!              0.6663
# 1460  Great game with alot of new features but it la...              0.8881
# 1844  can rule china buy trading rice.\n\nBroken Mar...              0.8457
# 382                 Absolute blast,\nBest TW ive played              0.8330
# 111   really good. everything you want in a total wa...              0.6664
#
#                                                  tokens  num_tokens  \
# 638                                ['one_best_entries']           1
# 1460  ['alot', 'new_features', 'design', 'romance', ...           5
# 1844      ['rule_china', 'trading', 'rice', 'marriage']           4
# 382                  ['blast', 'best_tw', 'ive_played']           3
# 111                                        ['wait_dlc']           1
#
#                                           unique_tokens  num_unique_tokens  \
# 638                                ['one_best_entries']                  1
# 1460  ['hero', 'design', 'alot', 'romance', 'new_fea...                  5
# 1844      ['trading', 'rule_china', 'rice', 'marriage']                  4
# 382                  ['blast', 'ive_played', 'best_tw']                  3
# 111                                        ['wait_dlc']                  1
#
#                                                keywords  correct
# 638   three_kingdoms, series, fan, diplomacy, battle...        1
# 1460  three_kingdoms, series, fan, diplomacy, battle...        1
# 1844  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...        0
# 382   three_kingdoms, series, fan, diplomacy, battle...        1
# 111   three_kingdoms, series, fan, diplomacy, battle...        1

# %%
samp_df = sample_token_mod_df.groupby(['num_tokens','correct'],as_index=False).count()[['num_tokens','correct','dominant_topic']] #To get row count, use any other column as last item in list

# %%
samp_df.columns = ['num_tokens','correct','count']

# %%
samp_df
# Out:
#     num_tokens  correct  count
# 0            0        0      8
# 1            0        1      5
# 2            1        0      9
# 3            1        1     24
# 4            2        0      7
# 5            2        1     44
# 6            3        0      9
# 7            3        1     34
# 8            4        0      6
# 9            4        1     31
# 10           5        1     16

# %%
#get misclassification percentages for each token class from 0 to 5 tokens

samp_perc_dict = {'num_tokens':[],'correct':[],'wrong':[],'total':[],'ms_cls_rate (%)':[]}

for i in range(6):
    token_correct = samp_df[(samp_df['num_tokens']==i)]['count'][samp_df['correct']==1].reset_index(drop=True)[0] #returns Series, must convert to scalar
    token_total = samp_df[(samp_df['num_tokens']==i)]['count'].sum()
    token_wrong = token_total - token_correct
    samp_perc_dict['num_tokens'].append(i)
    samp_perc_dict['correct'].append(token_correct)
    samp_perc_dict['wrong'].append(token_wrong)
    samp_perc_dict['total'].append(token_total)
    samp_perc_dict['ms_cls_rate (%)'].append(token_wrong/token_total*100)
    

samp_perc_dict
# Out:
# {'num_tokens': [0, 1, 2, 3, 4, 5],
#  'correct': [5, 24, 44, 34, 31, 16],
#  'wrong': [8, 9, 7, 9, 6, 0],
#  'total': [13, 33, 51, 43, 37, 16],
#  'ms_cls_rate (%)': [61.53846153846154,
#   27.27272727272727,
#   13.725490196078432,
#   20.930232558139537,
#   16.216216216216218,
#   0.0]}

# %%
samp_perc_df = pd.DataFrame(samp_perc_dict)
samp_perc_df
# Out:
#    num_tokens  correct  wrong  total  ms_cls_rate (%)
# 0           0        5      8     13        61.538462
# 1           1       24      9     33        27.272727
# 2           2       44      7     51        13.725490
# 3           3       34      9     43        20.930233
# 4           4       31      6     37        16.216216
# 5           5       16      0     16         0.000000

# %%
#While in this case 5 tokens has 0 inaccuracy, this is just a sample. Sometimes random chance leads to strange results.
#We can just take it as indication that higher token counts tend to have lower misclassification rates.

len(sample_token_mod_df[sample_token_mod_df['num_tokens']==5])
# Out:
# 16

# %%
#from the sample, reviews with num_tokens 0, 1, and 3 tokens seem to have the worst misclassification rates.
#However, since the sample for each class is so small, I will assess this data cumulatively...

cum_ms_cls_rate = np.cumsum(samp_perc_df['wrong'])/np.cumsum(samp_perc_df['total']) #cumulative misclassification rate

plt.figure(figsize=(10,6))
plt.bar(x=range(0,6),height=cum_ms_cls_rate)
plt.xlabel('Number of Tokens',fontsize = 14)
plt.ylabel('Cumul. Misclassification Rate (%)',fontsize = 14)
plt.title('Cumul. Misclassification Rate\n by Number of Tokens',fontsize = 18)
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
# Out:
# [Text(0, 0, '0%'),
#  Text(0, 0, '10%'),
#  Text(0, 0, '20%'),
#  Text(0, 0, '30%'),
#  Text(0, 0, '40%'),
#  Text(0, 0, '50%'),
#  Text(0, 0, '60%'),
#  Text(0, 0, '70%')]

# %%
#overall classification accuracy for reviews with 5 or fewer tokens

acc_5below = samp_perc_df['correct'].sum()/samp_perc_df['total'].sum()
acc_5below
# Out:
# 0.7979274611398963

# %%
#It seems that cumulatively, having 2 tokens and above will give lower misclassification rates (~25% as compared to above 35% for 1 token and below)
#Let's inspect the labelled dataframe and inspect num_tokens at the percentile levels
df_dominant_topic.describe()
# Out:
#        topic_perc_contrib   num_tokens  num_unique_tokens
# count         3661.000000  3661.000000        3661.000000
# mean             0.684212    13.361923          11.403169
# std              0.170385    25.330296          18.677219
# min              0.280800     0.000000           0.000000
# 25%              0.559500     2.000000           2.000000
# 50%              0.685500     5.000000           5.000000
# 75%              0.831500    13.000000          12.000000
# max              0.993400   342.000000         223.000000

# %%
#num_tokens 25th percentile is 2 -- we will have to sacrifice 25% of our dataset in order to use only data that is likely to be classified correctly 
#get class balance; we are going to check the labelling later
df_dominant_topic['dominant_topic'].value_counts(normalize=True)
# Out:
# Content & Authenticity           0.608850
# Tactical Gameplay                0.143950
# Characters                       0.107348
# UX/UI, Performance, Stability    0.075116
# Strategic Gameplay               0.064736
# Name: dominant_topic, dtype: float64

# %%
#There appears to be significant class imbalance, but it is expected. Reviewers tend to talk about how a game lives up to the series and/or genre it is from. 
#We will now sample 10% of the entire dataset at random (approximately 6% margin of error)

topic_weights = df_dominant_topic['dominant_topic']
sample_tokens_df_2 = df_dominant_topic.sample(frac=0.1,random_state=1337)
sample_tokens_df_2.head()
# Out:
#               dominant_topic  \
# 2875  Content & Authenticity
# 1662              Characters
# 3190  Content & Authenticity
# 948   Content & Authenticity
# 1541  Content & Authenticity
#
#                                           original_text  topic_perc_contrib  \
# 2875                      The best Total War out there.              0.6664
# 1662  My first time in the total war series. My play...              0.6446
# 3190  Many years ago I asked for Total War set in Ch...              0.9325
# 948   Great game, great graphics, love the time peri...              0.6613
# 1541  Big bad Dong is trying to rule China but not o...              0.5832
#
#                                                  tokens  num_tokens  \
# 2875                                   [best_total_war]           1
# 1662    [series, skip, work, vassal, bugger, yuan_shao]           6
# 3190  [years_ago, set_china, enjoy, lol, clown, empi...          10
# 948   [graphic, time_period, needs_work, faction, di...           6
# 1541                       [dong, rule_china, one_best]           3
#
#                                           unique_tokens  num_unique_tokens  \
# 2875                                   [best_total_war]                  1
# 1662    [series, bugger, work, yuan_shao, skip, vassal]                  6
# 3190  [enjoy, gaming, graphic, guy, lol, empire, lap...                 10
# 948   [faction, time_period, graphic, diplomacy, not...                  6
# 1541                       [one_best, rule_china, dong]                  3
#
#                                                keywords
# 2875  three_kingdoms, series, fan, diplomacy, battle...
# 1662  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 3190  three_kingdoms, series, fan, diplomacy, battle...
# 948   three_kingdoms, series, fan, diplomacy, battle...
# 1541  three_kingdoms, series, fan, diplomacy, battle...

# %%
sample_tokens_df_2.to_csv('./dataframes/sample_tokens_df_2.csv')

# %%
#import labelled sample_tokens_df

sample_token_mod_df = pd.read_csv('./dataframes/sample_tokens_df_2_mod.csv',index_col=0)

# %%
sample_token_mod_df.head()
# Out:
#            dominant_topic                                      original_text  \
# 3223   Strategic Gameplay  i like this game but im not sure about the sie...
# 189   Series Authenticity              Very nice game but needs some fixing.
# 860   Series Authenticity  I had never really played a Total War game bef...
# 1256    Tactical Gameplay  Great graphics, art style and one of the smoot...
# 3239       Game Stability  As a chinese, I think this game has gone deep ...
#
#       topic_perc_contrib                                             tokens  \
# 3223              0.7239                               ['im_sure', 'siege']
# 189               0.6617                                           ['need']
# 860               0.6003  ['unsure', 'fps', 'graphic', 'ancient_china', ...
# 1256              0.8454  ['graphic', 'art_style', 'gameplay', 'launch',...
# 3239              0.6055  ['romance_three_kingdoms', 'voice', 'line', 'l...
#
#       num_tokens                                      unique_tokens  \
# 3223           2                               ['im_sure', 'siege']
# 189            1                                           ['need']
# 860           12  ['graphic', 'unsure', 'shot', 'refund', 'reque...
# 1256         114  ['tactic', 'naval_combat', 'duel', 'compared_p...
# 3239          27  ['theme', 'kingdom', 'fps', 'gamer', 'optimiza...
#
#       num_unique_tokens                                           keywords  \
# 3223                  2  faction, army, diplomacy, vassal, war, player,...
# 189                   1  three_kingdoms, series, fan, diplomacy, battle...
# 860                  12  three_kingdoms, series, fan, diplomacy, battle...
# 1256                 91  unit, battle, faction, army, general, characte...
# 3239                 27  campaign, hour, issue, battle, bug, crash, mul...
#
#       correct
# 3223        0
# 189         0
# 860         1
# 1256        1
# 3239        1

# %%
samp_df = sample_token_mod_df.groupby(['num_tokens','correct'],as_index=False).count()[['num_tokens','correct','dominant_topic']]

# %%
samp_df.columns = ['num_tokens','correct','count']
count_df1 = samp_df.groupby(['correct'],as_index=False).sum()
count_df1
# Out:
#    correct  num_tokens  count
# 0        0         348     50
# 1        1        2395    316

# %%
ms_cls_rate2 = count_df1['count'][0]/count_df1['count'][1]
ms_cls_rate2
# Out:
# 0.15822784810126583

# %%
count_df2 = samp_df[samp_df['num_tokens']>1]
count_df2 = count_df2.groupby(['correct'],as_index=False).sum()
count_df2
# Out:
#    correct  num_tokens  count
# 0        0         347     35
# 1        1        2394    270

# %%
ms_cls_rate3 = count_df2['count'][0]/count_df2['count'][1]
ms_cls_rate3
# Out:
# 0.12962962962962962

# %%
count_df3 = samp_df[samp_df['num_tokens']>2]
count_df3 = count_df3.groupby(['correct'],as_index=False).sum()
count_df3
# Out:
#    correct  num_tokens  count
# 0        0         345     29
# 1        1        2392    226

# %%
ms_cls_rate4 = count_df3['count'][0]/count_df3['count'][1]
ms_cls_rate4
# Out:
# 0.12831858407079647

# %% [markdown]
# ### Findings from the samples
#
# Sample from data with num_tokens <=5:
# - The misclassficiation rate of the sample is between 14% and 22%, which I can accept for text analysis...
# - For the Internet is dark and full of errors.
# - More seriously, ~80% classification success rate from an unsupervised model seems quite usable.
# - Of course, this is most likely because in the first place, most of the reviews are about Series Authenticity. Most reviews say "Best Total War yet!" or something to that effect.
#
# In any case, the model seems quite usable based on this initial analysis.
#
# Sample from data with any number of tokens:
# - The misclassification rate of the sample (10% of the whole dataset) is around 16%, which I find, once again, to be quite acceptable.
# - Given that the sample was was 366 and it was a substantial chunk of the dataset, the rate should be approximately the same for the dataset.
# - Long reviews tend to cover multiple topics. To classify one entire review as being about one topic is one way of doing things, but it could mean wasted opportunities...
# - When reviews with 1 or 0 tokens are dropped, the misclassification rate drops from ~16% to ~13%.
# - When reviews with 2 or fewer tokens are dropped, the misclassification rate drops only very slightly, from 12.9% to 12.8%.
#     - The tradeoff is not worth it. A lot more data is lost for only a tiny marginal gain in accuracy of classification.
#
# General:
# - The Game Stability topic also includes discussions of general performance and optimisation. Perhaps it should be renamed to Performance & Stability.
#
# **NEXT STEPS**
#
# - Remove reviews that have 0 or 1 tokens from the dataset
# - Analyse the entire corpus by sentences instead of by document.
#     - This way, there will be more data overall; long reviews can be broken down into parts that talk about different topics.
# - The resulting topics and sentiments can be grouped together for a more accurate overview of player sentiment overall, rather than sentiment for the dominant topic of each document

# %%
#rename Game Stability to Performance & Stability
df_dominant_topic['dominant_topic'] = df_dominant_topic['dominant_topic'].replace('Game Stability','Performance & Stability')

#Remove reviews with 1 or 0 tokens

df_dominant_topic2=df_dominant_topic[df_dominant_topic['num_tokens']>1]

#Find out what proportion of reviews were dropped
rows_removed = abs(len(df_dominant_topic)-len(df_dominant_topic2))/len(df_dominant_topic)
print(rows_removed)
# Out:
# 0.1434818256354195

# %%
#Get number of reviews remaining

len(df_dominant_topic2)
# Out:
# 3134

# %%
df_dominant_topic.to_csv('./dataframes/dominant_topics.csv')

# %% [markdown]
# # Final Validation
#
# After previous sampling, realised that training data should not be used to test the model.
#
# NOTE: Before this section was added, this notebook was thought complete and Sentiment Analysis was done. So, this section includes methodology established in Sentiment Analysis.

# %%
request_params = dict()
request_params['filter'] = 'recent'
request_params['language'] = 'english'
request_params['day_range'] = '365'

app_id = 779340
review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id, chosen_request_params=request_params)
# Out:
# [appID = 779340] expected #reviews = 8462

# %%
#read in a json file
with open('./data/review_779340_2.json') as jsonfile:
    jayson = json.load(jsonfile)

# %%
review_data = [v for v in jayson['reviews'].values()]
author_key_list = list(review_data[0]['author'].keys())

# %%
len(review_data)
# Out:
# 8422

# %%
datetime.datetime.utcfromtimestamp(min([review_data[i]['timestamp_created'] for i in range(len(review_data))])).strftime('%Y-%m-%d')
# Out:
# '2019-05-23'

# %%
datetime.datetime.utcfromtimestamp(max([review_data[i]['timestamp_created'] for i in range(len(review_data))])).strftime('%Y-%m-%d')
# Out:
# '2019-07-20'

# %%
#previous max value was 1562591773; 2019-07-08
max([review_data[i]['timestamp_created'] for i in range(len(review_data))])
# Out:
# 1563618842

# %%
#for definition of each field in the JSON files, visit (here)[https://partner.steamgames.com/doc/store/getreviews]

steam_dict = {'recommendationid':[review_data[i]['recommendationid'] for i in range(len(review_data))],
              
              'author_steamid':[review_data[i]['author']['steamid'] for i in range(len(review_data))],
              
              'author_num_games_owned':[review_data[i]['author']['num_games_owned'] for i in range(len(review_data))],
              
              'author_num_reviews':[review_data[i]['author']['num_reviews'] for i in range(len(review_data))],
              
              'author_playtime_forever':[review_data[i]['author']['playtime_forever'] for i in range(len(review_data))], 
              #data recorded in minutes - independently verified: https://steamcommunity.com/id/mydogsnameissnowballball/recommended/730/ - 43586 divided by 724.6h on record = 60 min
              
              'author_playtime_last_two_weeks':[review_data[i]['author']['playtime_last_two_weeks'] for i in range(len(review_data))],
              
              'author_last_played':[review_data[i]['author']['last_played'] for i in range(len(review_data))],
              
              'review':[review_data[i]['review'] for i in range(len(review_data))],
              
              'timestamp_created':[review_data[i]['timestamp_created'] for i in range(len(review_data))],
              
              'timestamp_updated':[review_data[i]['timestamp_updated'] for i in range(len(review_data))],
              
              'voted_up':[review_data[i]['voted_up'] for i in range(len(review_data))],
              
              'weighted_vote_score':[review_data[i]['weighted_vote_score'] for i in range(len(review_data))],
              
              'steam_purchase':[review_data[i]['steam_purchase'] for i in range(len(review_data))],
              
              'received_for_free':[review_data[i]['received_for_free'] for i in range(len(review_data))],
              
              'written_during_early_access':[review_data[i]['written_during_early_access'] for i in range(len(review_data))]}

# %%
df_raw = pd.DataFrame(steam_dict)
df_raw.head(2)
# Out:
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         54192944  76561198859964653                      57
# 1         54192696  76561198433597055                       2
#
#    author_num_reviews  author_playtime_forever  \
# 0                  24                     1694
# 1                   1                     7441
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                            1694          1563886009
# 1                            4943          1563870098
#
#                                               review  timestamp_created  \
# 0  Its a chess within a chess, two layers of comp...         1563618842
# 1  Please give us more Chinese theme game.I will ...         1563617491
#
#    timestamp_updated  voted_up   weighted_vote_score  steam_purchase  \
# 0         1563810779      True  0.495412856340408325            True
# 1         1563617491      True  0.523809552192687988            True
#
#    received_for_free  written_during_early_access
# 0              False                        False
# 1              False                        False

# %%
len(df_raw['recommendationid'].unique())
# Out:
# 8422

# %%
df_raw = df_raw[df_raw['received_for_free']==False] # Redundant for F2P games, because nobody can buy them

# %%
df_raw.dtypes
# Out:
# recommendationid                  object
# author_steamid                    object
# author_num_games_owned             int64
# author_num_reviews                 int64
# author_playtime_forever            int64
# author_playtime_last_two_weeks     int64
# author_last_played                 int64
# review                            object
# timestamp_created                  int64
# timestamp_updated                  int64
# voted_up                            bool
# weighted_vote_score               object
# steam_purchase                      bool
# received_for_free                   bool
# written_during_early_access         bool
# dtype: object

# %%
df_raw = df_raw[df_raw['timestamp_created']>1562591773]

# %%
len(df_raw)
# Out:
# 206

# %%
df_raw.describe()
# Out:
#        author_num_games_owned  author_num_reviews  author_playtime_forever  \
# count              206.000000          206.000000               206.000000
# mean               136.820388           12.461165              4731.038835
# std                157.885700           20.120514              4680.173901
# min                  1.000000            1.000000                30.000000
# 25%                 36.250000            2.000000              1318.000000
# 50%                 96.000000            5.000000              3315.500000
# 75%                179.750000           14.000000              6401.000000
# max               1417.000000          142.000000             24184.000000
#
#        author_playtime_last_two_weeks  author_last_played  timestamp_created  \
# count                      206.000000        2.060000e+02       2.060000e+02
# mean                      1242.344660        1.563050e+09       1.563089e+09
# std                       1543.339617        1.106116e+06       2.940085e+05
# min                          0.000000        1.558703e+09       1.562595e+09
# 25%                         33.500000        1.562953e+09       1.562823e+09
# 50%                        688.000000        1.563451e+09       1.563075e+09
# 75%                       1872.000000        1.563786e+09       1.563361e+09
# max                       9085.000000        1.563886e+09       1.563619e+09
#
#        timestamp_updated
# count       2.060000e+02
# mean        1.563102e+09
# std         3.000377e+05
# min         1.562595e+09
# 25%         1.562849e+09
# 50%         1.563089e+09
# 75%         1.563374e+09
# max         1.563811e+09

# %%
df_raw['author_playtime_forever']=df_raw['author_playtime_forever']/60
df_raw['author_playtime_last_two_weeks']=df_raw['author_playtime_last_two_weeks']/60

# %%
df_raw_num = df_raw.select_dtypes(exclude=['O','bool'])

# %%
df_raw_num_high_play = df_raw_num[(df_raw_num['author_playtime_forever']>2) & (df_raw_num['author_playtime_last_two_weeks']>=0.5)]

# %%
len(df_raw_num_high_play)
# Out:
# 150

# %%
df_usable = df_raw[(df_raw['author_playtime_forever']>=3)& (df_raw_num['author_playtime_last_two_weeks']>=(10/60))] #recent opinions are more important, and user must have played longer than refundable playtime cutoff
df_usable.head(2)
# Out:
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         54192944  76561198859964653                      57
# 1         54192696  76561198433597055                       2
#
#    author_num_reviews  author_playtime_forever  \
# 0                  24                28.233333
# 1                   1               124.016667
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                       28.233333          1563886009
# 1                       82.383333          1563870098
#
#                                               review  timestamp_created  \
# 0  Its a chess within a chess, two layers of comp...         1563618842
# 1  Please give us more Chinese theme game.I will ...         1563617491
#
#    timestamp_updated  voted_up   weighted_vote_score  steam_purchase  \
# 0         1563810779      True  0.495412856340408325            True
# 1         1563617491      True  0.523809552192687988            True
#
#    received_for_free  written_during_early_access
# 0              False                        False
# 1              False                        False

# %%
review_lengths = [len(x.split()) for x in df_usable['review']]
print(len(review_lengths)) #no of reviews
print(sum(review_lengths)/len(review_lengths)) #mean character length of a review
df_usable['review_length']=df_usable['review'].map(lambda x: len(x.split()))
# Out:
# 153
# 82.359477124183
# C:\Users\Alfred\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_ready = df_usable[df_usable['review_length']>np.percentile(df_usable['review_length'],25)].reset_index(drop=True) #Remove very short reviews that are likely to be junk

# %%
print(min(df_ready['review_length'])) #shortest review length, in words. space-delimited
df_ready.head(2)
# Out:
# 12
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         54183390  76561197984368747                     216
# 1         54183023  76561198451245786                     155
#
#    author_num_reviews  author_playtime_forever  \
# 0                   6                69.933333
# 1                   4                58.450000
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                        0.300000          1563395139
# 1                        2.566667          1563617150
#
#                                               review  timestamp_created  \
# 0  Awesome. Great game! \n\nDo wish they gave you...         1563562610
# 1  became emperor of china then everyone betrayed...         1563560850
#
#    timestamp_updated  voted_up weighted_vote_score  steam_purchase  \
# 0         1563562610      True                   0           False
# 1         1563560850      True                   0           False
#
#    received_for_free  written_during_early_access  review_length
# 0              False                        False             80
# 1              False                        False             14

# %%
#drop duplicate entries in reviews, because they are considered spam
df_cleaning = df_ready.drop_duplicates(subset='review')

# %%
df_cleaning.select_dtypes(include='O').describe()
# Out:
#        recommendationid     author_steamid  \
# count               111                111
# unique              111                111
# top            54032935  76561198007691650
# freq                  1                  1
#
#                                                    review  weighted_vote_score
# count                                                 111                  111
# unique                                                111                   49
# top     I'm usually not a fan of total war but this ga...                    0
# freq                                                    1                   53

# %%
deduplicated_rows = abs(len(df_cleaning) - len(df_ready)) #find out how many rows were removed during deduplication
print(deduplicated_rows)
print(deduplicated_rows/len(df_ready)) #Percentage of data that was duplicated
# Out:
# 0
# 0.0

# %%
#get languages by document
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe(LanguageDetector(), name="language_detector", last=True)
    
def get_lang_doc(text):
    doc = nlp(text)
    return doc._.language['language']

#count languages for sentences in document -- decided not to use this because 1. it slows computation a lot 2. it throws a lot of false positives, especially when splitting short lines
def get_langs_sent(text):
    langs={}
    lang_st={}
    doc = nlp(text)
    
    for i, sent in enumerate(doc.sents):
        langs[i]=sent._.language['language'] #Iterating through sentence level, thus only need to add language. Probability scores should be quite high per sentence.
    
    lang_st = list(set(langs.values())) #Get language code of each language that appeared. As long as more than 1 language appears, the review will be excluded.
    
    return lang_st

# %%
#No repeated reviews.

doc_langs = [get_lang_doc(x) for x in df_cleaning['review']] #WARNING: SLOW! May take a couple of minutes to finish.
df_cleaning['review_lang']=doc_langs

# %%
df_cleaning.to_csv('./dataframes/vldtn_test_cleaning.csv') #saving so I don't have to run the cleaning operation again

# %%
df_cleaning = pd.read_csv('./dataframes/vldtn_test_cleaning.csv',index_col=0)

# %%
df_langs_cleaned = df_cleaning[df_cleaning['review_lang']=='en'].reset_index(drop=True)
len(df_langs_cleaned)
# Out:
# 111

# %%
mult_ln_reviews_dropped = (len(df_cleaning) - len(df_langs_cleaned))/len(df_cleaning)
print(mult_ln_reviews_dropped)
# Out:
# 0.0

# %%
parser = bbcode.Parser()

def parse(review):
    parsed_text = parser.strip(review)
    return parsed_text

#open pre-defined dictionary of english contractions, saved separately to avoid clutter (long dictionary, can be loaded as dict using json package)
with open('./en_contractions/contra_dict.txt') as contra_dict:
    cList = json.load(contra_dict)

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text.lower())

# %%
def parse_sent_tokenize(review):
    
    sent_tokens = [] #store sentence tokens here
    
    text = parse(review)  #remove BBcode first
    
    text = expandContractions(text)
    
    #All word lengths should be >1 character and <= length of the longest word in the English language. It's common for people spam incoherent letters on the Internet. Do not remove stopwords yet.
    text = [word for word in text.split() if len(word)>1 and len(word) <= len('pneumonoultramicroscopicsilicovolcanoconiosis')] 
   
    parsed_text = ' '.join(word for word in text)
    
    doc = nlp(parsed_text)
    for i,sent in enumerate(doc.sents):
        sent_tokens.append(sent.text)
    
    return sent_tokens

#remove punctuation
def remove_punc(sents):
    clean_text = [s.translate(str.maketrans('', '', string.punctuation)) 
                  for s in sents]
    return clean_text

# %%
df_langs_cleaned.head(2)
# Out:
#    recommendationid     author_steamid  author_num_games_owned  \
# 0          54183390  76561197984368747                     216
# 1          54183023  76561198451245786                     155
#
#    author_num_reviews  author_playtime_forever  \
# 0                   6                69.933333
# 1                   4                58.450000
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                        0.300000          1563395139
# 1                        2.566667          1563617150
#
#                                               review  timestamp_created  \
# 0  Awesome. Great game! \n\nDo wish they gave you...         1563562610
# 1  became emperor of china then everyone betrayed...         1563560850
#
#    timestamp_updated  voted_up  weighted_vote_score  steam_purchase  \
# 0         1563562610      True                  0.0           False
# 1         1563560850      True                  0.0           False
#
#    received_for_free  written_during_early_access  review_length review_lang
# 0              False                        False             80          en
# 1              False                        False             14          en

# %%
big_sent_lst =[] #For storing ALL sentences in the dataset. Doesn't matter which reviews they came from

review_index_lst = [] #for storing all index numbers for each sentence so we can identify which reviews they belong to and thus group scores by topics and reviews

sent_df = pd.DataFrame() #For visualisation of sentence transformations and saving of data

review_count = 0
for review in df_langs_cleaned['review']:
    sent_tokens = parse_sent_tokenize(review)
    sent_tokens = remove_punc(sent_tokens)
    big_sent_lst.extend(sent_tokens)
    
    review_count+=1
    review_num_lst = [str(review_count)] * len(sent_tokens) #for each review, create list of corresponding review index numbers that is as long as the number of sentences for easier groupby
    review_index_lst.extend(review_num_lst)

sent_df['original_sent'] = [x for x in big_sent_lst]
sent_df['test_set_review_number'] = review_index_lst
sent_df['token_sentences'] = [x.split() for x in big_sent_lst]

sent_df.head(2)
# Out:
#                                        original_sent test_set_review_number  \
# 0                                            awesome                      1
# 1  great game do wish they gave you more factions...                      1
#
#                                      token_sentences
# 0                                          [awesome]
# 1  [great, game, do, wish, they, gave, you, more,...

# %%
#load dataset for training ngram phraser

final_data = pd.read_csv('./dataframes/dominant_topics.csv',index_col=0)

# %%
final_data.head()
# Out:
#         dominant_topic                                      original_text  \
# 0    Tactical Gameplay  Well for me game still tons of work. i like it...
# 1           Characters            I pursued Lu Bu. Now I [b]AM[/b] LU BU.
# 2  Series Authenticity  Absolutely great game. \nAll the new diplomacy...
# 3  Series Authenticity  A fine blend of Warhammer I/II: Total War and ...
# 4  Series Authenticity  Innovative Total Game that has lots of persona...
#
#    topic_perc_contrib                                             tokens  \
# 0              0.4715  ['ton', 'diplomacy', 'joke', 'military_access'...
# 1              0.7433                                 ['lu_bu', 'lu_bu']
# 2              0.9391  ['diplomacy_options', 'depth', 'unit_variety',...
# 3              0.6487  ['blend', 'warhammer_three', 'shogun_two', 'lo...
# 4              0.7290  ['personality', 'diplomacy', 'idea', 'combat',...
#
#    num_tokens                                      unique_tokens  \
# 0          85  ['guess', 'artillery', 'chain', 'siege', 'sent...
# 1           2                                          ['lu_bu']
# 2          10  ['warhammer', 'depth', 'combat', 'rt', 'diplom...
# 3          20  ['blend', 'warhammer_three', 'character', 'bat...
# 4          11  ['art_style', 'paid_dlc', 'combat', 'content',...
#
#    num_unique_tokens                                           keywords
# 0                 57  unit, battle, faction, army, general, characte...
# 1                  1  china, war, cao_cao, lu_bu, liu_bei, yuan_shao...
# 2                  9  three_kingdoms, series, fan, diplomacy, battle...
# 3                 20  three_kingdoms, series, fan, diplomacy, battle...
# 4                 10  three_kingdoms, series, fan, diplomacy, battle...

# %%
#initialise BBcode parser and spacy NLP for parsing and tokenising sentences

nlp = spacy.load("en_core_web_sm")
parser = bbcode.Parser()

def parse(review):
    parsed_text = parser.strip(review)
    return parsed_text

#open pre-defined dictionary of english contractions, saved separately to avoid clutter (long dictionary, can be loaded as dict using json package)
with open('./en_contractions/contra_dict.txt') as contra_dict:
    cList = json.load(contra_dict)

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text.lower())

# %%
big_sent_lst2 =[] #For storing ALL sentences in the dataset. Doesn't matter which reviews they came from
train_sent_df = pd.DataFrame() #For visualisation of sentence transformations and saving of data

for review in final_data['original_text']:
    sent_tokens = parse_sent_tokenize(review)
    sent_tokens = remove_punc(sent_tokens)
    big_sent_lst2.extend(sent_tokens)

# %%
train_sent_df['original_text'] = [x for x in big_sent_lst2]
train_sent_df['token_sentences'] = [x.split() for x in big_sent_lst2]
train_sent_df.head()
# Out:
#                          original_text  \
# 0  well for me game still tons of work
# 1      like it but just cant recommend
# 2                                    1
# 3                            diplomacy
# 4                           it is joke
#
#                                 token_sentences
# 0  [well, for, me, game, still, tons, of, work]
# 1        [like, it, but, just, cant, recommend]
# 2                                           [1]
# 3                                   [diplomacy]
# 4                                [it, is, joke]

# %%
def num2word(d):
    
    if (len(d) == 1 and d in '0123')  or (d in ['ii','iii']):
        word = num_dict[d]
    
    elif (len(str(d))==1 and str(d) in '0123'):
        word = num_dict(str(d))
    
    else:
        word = d
    
    return word

en_stopwords = list(set(STOPWORDS))
en_stopwords.extend(['good','better','great','lot','game','like','I','i'])
en_stopwords = [w for w in en_stopwords if w not in ['one','two','three']]

def remove_stopwords(doc):
    words = [num2word(w) for w in doc if w != '' and w not in en_stopwords]
    return words

train_sent_df['sents_unstopped'] = train_sent_df['token_sentences'].map(lambda x: remove_stopwords(x))

bigram = gensim.models.Phrases(list(train_sent_df['sents_unstopped']), min_count=5, threshold=10) # feed a list of lists of words e.g. [['word1','word2'],['word3','word4'] to get bigrams]
trigram = gensim.models.Phrases(bigram[list(train_sent_df['sents_unstopped'])], threshold=10)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

#at this point we will make n-grams, then lemmatise using spacy since it can go by permitted postags

def spacy_lemma(bow,allowed_postags=['NOUN']):
    
    lemma_doc = nlp(" ".join(bow)) 

    lemma_text = [token.text if '_' in token.text else token.lemma_ if token.pos_ in allowed_postags else '' for token in lemma_doc]
    
    return lemma_text

# %%
#WARNING! this cell can be a little slow, especially with larger datasets (it already takes ~3 minutes with 3600+ rows) -- will consider stemming as a future modification

sent_df['sents_unstopped'] = sent_df['token_sentences'].map(lambda x: remove_stopwords(x))
sent_df['3gram_sentences'] = make_trigrams(sent_df['sents_unstopped'])

en_stopwords.extend(['good','better','great','lot','game','like','I','i','one','two','three','thing','bit','total_war','time'])

sent_df['3gram_sentences_lemma'] = sent_df['3gram_sentences'].map(lambda x: spacy_lemma(x))
sent_df['3gram_sentences_clean'] = sent_df['3gram_sentences_lemma'].map(lambda x: remove_stopwords(x))
sent_df.head(10)
# Out:
#                                        original_sent test_set_review_number  \
# 0                                            awesome                      1
# 1  great game do wish they gave you more factions...                      1
# 2  the whole bottom of the map is empty which mea...                      1
# 3  really enjoy how romance of the three kingdoms...                      1
# 4  those are minor complaints to great and amazin...                      1
# 5  my favorite total war series to date and have ...                      1
# 6  became emperor of china then everyone betrayed...                      2
# 7  graphics you forget what reality is beautiful ...                      3
# 8  audience kids teens adults average solitare pl...                      3
# 9  decent fast rich boiiiiii ask nasa if they hav...                      3
#
#                                      token_sentences  \
# 0                                          [awesome]
# 1  [great, game, do, wish, they, gave, you, more,...
# 2  [the, whole, bottom, of, the, map, is, empty, ...
# 3  [really, enjoy, how, romance, of, the, three, ...
# 4  [those, are, minor, complaints, to, great, and...
# 5  [my, favorite, total, war, series, to, date, a...
# 6  [became, emperor, of, china, then, everyone, b...
# 7  [graphics, you, forget, what, reality, is, bea...
# 8  [audience, kids, teens, adults, average, solit...
# 9  [decent, fast, rich, boiiiiii, ask, nasa, if, ...
#
#                                      sents_unstopped  \
# 0                                          [awesome]
# 1     [wish, gave, factions, starting, map, options]
# 2           [map, means, wu, takes, free, territory]
# 3  [enjoy, romance, three, kingdoms, lets, play, ...
# 4                       [minor, complaints, amazing]
# 5  [favorite, total, war, series, date, pretty, p...
# 6   [emperor, china, betrayed, 1010, reunite, china]
# 7  [graphics, forget, reality, beautiful, decent,...
# 8  [audience, kids, teens, adults, average, solit...
# 9  [decent, fast, rich, boiiiiii, ask, nasa, spar...
#
#                                      3gram_sentences  \
# 0                                          [awesome]
# 1     [wish, gave, factions, starting, map, options]
# 2           [map, means, wu, takes, free, territory]
# 3  [enjoy, romance_three_kingdoms, lets, play, wa...
# 4                       [minor, complaints, amazing]
# 5  [favorite_total_war, series, date, pretty, pla...
# 6   [emperor, china, betrayed, 1010, reunite, china]
# 7  [graphics, forget, reality, beautiful, decent,...
# 8  [audience, kids, teens, adults, average, solit...
# 9  [decent, fast, rich, boiiiiii, ask, nasa, spar...
#
#                                3gram_sentences_lemma  \
# 0                                                 []
# 1                   [wish, , faction, , map, option]
# 2                           [map, , , , , territory]
# 3  [, romance_three_kingdoms, let, , , , , starti...
# 4                                    [, complaint, ]
# 5  [favorite_total_war, series, date, , , medievial]
# 6               [emperor, china, , , reunite, china]
# 7  [graphic, , reality, , , , don‘t, , , paintexe...
# 8  [audience, kid, teen, adult, , , player, pc, r...
# 9  [, , , boiiiiii, , nasa, , difficulity, press,...
#
#                                3gram_sentences_clean
# 0                                                 []
# 1                       [wish, faction, map, option]
# 2                                   [map, territory]
# 3  [romance_three_kingdoms, let, starting, map, o...
# 4                                        [complaint]
# 5      [favorite_total_war, series, date, medievial]
# 6                   [emperor, china, reunite, china]
# 7  [graphic, reality, don‘t, paintexe, gameplay, ...
# 8  [audience, kid, teen, adult, player, pc, requi...
# 9  [boiiiiii, nasa, difficulity, press, ‚, brain,...

# %%
sent_df['num_tokens']=sent_df['3gram_sentences_clean'].map(lambda x: len(x))
sent_df.head()
# Out:
#                                        original_sent test_set_review_number  \
# 0                                            awesome                      1
# 1  great game do wish they gave you more factions...                      1
# 2  the whole bottom of the map is empty which mea...                      1
# 3  really enjoy how romance of the three kingdoms...                      1
# 4  those are minor complaints to great and amazin...                      1
#
#                                      token_sentences  \
# 0                                          [awesome]
# 1  [great, game, do, wish, they, gave, you, more,...
# 2  [the, whole, bottom, of, the, map, is, empty, ...
# 3  [really, enjoy, how, romance, of, the, three, ...
# 4  [those, are, minor, complaints, to, great, and...
#
#                                      sents_unstopped  \
# 0                                          [awesome]
# 1     [wish, gave, factions, starting, map, options]
# 2           [map, means, wu, takes, free, territory]
# 3  [enjoy, romance, three, kingdoms, lets, play, ...
# 4                       [minor, complaints, amazing]
#
#                                      3gram_sentences  \
# 0                                          [awesome]
# 1     [wish, gave, factions, starting, map, options]
# 2           [map, means, wu, takes, free, territory]
# 3  [enjoy, romance_three_kingdoms, lets, play, wa...
# 4                       [minor, complaints, amazing]
#
#                                3gram_sentences_lemma  \
# 0                                                 []
# 1                   [wish, , faction, , map, option]
# 2                           [map, , , , , territory]
# 3  [, romance_three_kingdoms, let, , , , , starti...
# 4                                    [, complaint, ]
#
#                                3gram_sentences_clean  num_tokens
# 0                                                 []           0
# 1                       [wish, faction, map, option]           4
# 2                                   [map, territory]           2
# 3  [romance_three_kingdoms, let, starting, map, o...           5
# 4                                        [complaint]           1

# %%
test_sent_df = sent_df[sent_df['num_tokens']>1].reset_index(drop=True)
dropped_rows = abs(len(sent_df)-len(test_sent_df))/len(sent_df)
print(dropped_rows)
print(len(test_sent_df))
# Out:
# 0.328
# 504

# %%
#Proportion of test set sentences vs the training set

497/10961
# Out:
# 0.04534257823191315

# %%
#In hindsight, I should have reserved 20% of the data for testing.

test_sent_df.describe()
# Out:
#        num_tokens
# count  504.000000
# mean     4.146825
# std      2.777048
# min      2.000000
# 25%      2.000000
# 50%      3.000000
# 75%      5.000000
# max     26.000000

# %%
test_sent_df.to_csv('./dataframes/vldtn_test_df.csv')

# %%
test_sent_df = pd.read_csv('./dataframes/vldtn_test_df.csv',index_col=0)

# %%
test_sent_df.head(2)
# Out:
#                                        original_sent  test_set_review_number  \
# 0  great game do wish they gave you more factions...                       1
# 1  the whole bottom of the map is empty which mea...                       1
#
#                                      token_sentences  \
# 0  ['great', 'game', 'do', 'wish', 'they', 'gave'...
# 1  ['the', 'whole', 'bottom', 'of', 'the', 'map',...
#
#                                      sents_unstopped  \
# 0  ['wish', 'gave', 'factions', 'starting', 'map'...
# 1  ['map', 'means', 'wu', 'takes', 'free', 'terri...
#
#                                      3gram_sentences  \
# 0  ['wish', 'gave', 'factions', 'starting', 'map'...
# 1  ['map', 'means', 'wu', 'takes', 'free', 'terri...
#
#                           3gram_sentences_lemma  \
# 0  ['wish', '', 'faction', '', 'map', 'option']
# 1          ['map', '', '', '', '', 'territory']
#
#                   3gram_sentences_clean  num_tokens
# 0  ['wish', 'faction', 'map', 'option']           4
# 1                  ['map', 'territory']           2

# %%
test_sent_df.dtypes
# Out:
# original_sent             object
# test_set_review_number     int64
# token_sentences           object
# sents_unstopped           object
# 3gram_sentences           object
# 3gram_sentences_lemma     object
# 3gram_sentences_clean     object
# num_tokens                 int64
# dtype: object

# %%
test_sent_df['token_sentences'] = test_sent_df['token_sentences'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split()) #n-grams underscores must be preserved for readability
test_sent_df['sents_unstopped'] = test_sent_df['sents_unstopped'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split()) 
test_sent_df['3gram_sentences'] = test_sent_df['3gram_sentences'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split()) 
test_sent_df['3gram_sentences_clean'] = test_sent_df['3gram_sentences_clean'].map(lambda x: ''.join(c for c in x if c=='_' or c not in string.punctuation).split())

# %%
test_sent_df.head(2)
# Out:
#                                        original_sent  test_set_review_number  \
# 0  great game do wish they gave you more factions...                       1
# 1  the whole bottom of the map is empty which mea...                       1
#
#                                      token_sentences  \
# 0  [great, game, do, wish, they, gave, you, more,...
# 1  [the, whole, bottom, of, the, map, is, empty, ...
#
#                                   sents_unstopped  \
# 0  [wish, gave, factions, starting, map, options]
# 1        [map, means, wu, takes, free, territory]
#
#                                   3gram_sentences  \
# 0  [wish, gave, factions, starting, map, options]
# 1        [map, means, wu, takes, free, territory]
#
#                           3gram_sentences_lemma         3gram_sentences_clean  \
# 0  ['wish', '', 'faction', '', 'map', 'option']  [wish, faction, map, option]
# 1          ['map', '', '', '', '', 'territory']              [map, territory]
#
#    num_tokens
# 0           4
# 1           2

# %%
documents = list(test_sent_df['3gram_sentences_clean'])
dictionary = gensim.corpora.Dictionary(documents)

dictionary.filter_extremes(no_below = 5,no_above=0.5)     

corpus = [dictionary.doc2bow(text) for text in documents]

# %%
topic_list = lda_model.print_topics(num_topics=5, num_words=15)
for index, i in enumerate(topic_list):
    str1 = str(i[1])
    for c in "0123456789+*\".":
        str1 = str1.replace(c, "")
    str1 = str1.replace("  ", " ")
    print(str1)
# Out:
# three_kingdoms series fan diplomacy battle love best_total_war campaign total_war_games fun character shogun play title gameplay
# china war cao_cao lu_bu liu_bei yuan_shao army character man emperor warlord friend history faction sun_jian
# faction army diplomacy vassal war player people way city problem campaign option spy three_kingdoms review
# unit battle faction army general character diplomacy campaign hero building duel enemy way map combat
# campaign hour issue battle bug crash multiplayer review rome fix play patch work month release

# %%
#credit to https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/ for this cell's code, which I modified to suit my needs

topic_dict = {'0':'Content & Authenticity',
              '1':'Characters',
              '2':'Strategic Gameplay',
              '3':'Tactical Gameplay',
              '4':'UX, Performance, Stability',
             }

#created a dictionary so I can show topic names instead of numbers, without any complicated code

def format_topics_sentences(ldamodel=lda_model, corpus=corpus, documents=documents):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([topic_dict[str(topic_num)], round(prop_topic,4), topic_keywords]), ignore_index=True)   #replaced int(topic_num) with
                
            else:
                break
                
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    orig_contents = pd.Series(test_sent_df['original_sent'])
    docs = pd.Series(documents)
    sent_topics_df = pd.concat([sent_topics_df,docs, orig_contents], axis=1)
    return(sent_topics_df)

# %%
#generate dataframe
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, documents=documents)

# %%
# Format dataframe
df_sent_dom_topic = df_topic_sents_keywords.reset_index()

df_sent_dom_topic.columns = ['document_no', 'dominant_topic', 'topic_perc_contrib', 'keywords', 'tokens','original_text']

df_sent_dom_topic['num_tokens']=df_sent_dom_topic['tokens'].map(lambda x: len(x))
df_sent_dom_topic['review_number'] = test_sent_df['test_set_review_number']

df_sent_dom_topic = df_sent_dom_topic[['review_number','dominant_topic','original_text','topic_perc_contrib','tokens','num_tokens','keywords']]

# Show dataframe
df_sent_dom_topic.head(5)
# Out:
#    review_number      dominant_topic  \
# 0              1  Strategic Gameplay
# 1              1  Strategic Gameplay
# 2              1  Strategic Gameplay
# 3              1   Tactical Gameplay
# 4              2   Tactical Gameplay
#
#                                        original_text  topic_perc_contrib  \
# 0  great game do wish they gave you more factions...              0.7929
# 1  the whole bottom of the map is empty which mea...              0.5874
# 2  really enjoy how romance of the three kingdoms...              0.7243
# 3  my favorite total war series to date and have ...              0.5686
# 4  became emperor of china then everyone betrayed...              0.7038
#
#                                               tokens  num_tokens  \
# 0                       [wish, faction, map, option]           4
# 1                                   [map, territory]           2
# 2  [romance_three_kingdoms, let, starting, map, o...           5
# 3      [favorite_total_war, series, date, medievial]           4
# 4                   [emperor, china, reunite, china]           4
#
#                                             keywords
# 0  faction, army, diplomacy, vassal, war, player,...
# 1  faction, army, diplomacy, vassal, war, player,...
# 2  faction, army, diplomacy, vassal, war, player,...
# 3  unit, battle, faction, army, general, characte...
# 4  unit, battle, faction, army, general, characte...

# %%
df_sent_dom_topic.to_csv('./dataframes/vldtn_test_sent_topics.csv')

# %%
make_trigrams([['shogun','two','shogun','2']])
# Out:
# [['shogun_two', 'shogun', '2']]

# %%
spacy_lemma(['map'])
# Out:
# ['']

# %%
spacy_lemma(['crashing'])
# Out:
# ['']

# %%
spacy_lemma(['crash'])
# Out:
# ['crash']

# %%
df_sent_dom_topic[30:35]
# Out:
#     review_number          dominant_topic  \
# 30              8  Content & Authenticity
# 31              9      Strategic Gameplay
# 32              9  Content & Authenticity
# 33              9      Strategic Gameplay
# 34             10      Strategic Gameplay
#
#                                         original_text  topic_perc_contrib  \
# 30  many are very similar and had to constantly ch...              0.3328
# 31  this is the only total war game have not been ...              0.4194
# 32  today decided to just uninstall it and move on...              0.3328
# 33  fan of the era itself or 2 have been too spoil...              0.3606
# 34  this game is amazing although the controls wer...              0.7893
#
#                                                tokens  num_tokens  \
# 30                                  [picture, person]           2
# 31  [finish, week, release, everytime, play, quality]           6
# 32                                   [today, forcing]           2
# 33  [fan, era, spoilt, term, fan, rome, warhammer,...          10
# 34  [control, makes_feel, china, chinese_culture, ...           5
#
#                                              keywords
# 30  three_kingdoms, series, fan, diplomacy, battle...
# 31  faction, army, diplomacy, vassal, war, player,...
# 32  three_kingdoms, series, fan, diplomacy, battle...
# 33  faction, army, diplomacy, vassal, war, player,...
# 34  faction, army, diplomacy, vassal, war, player,...

# %% [markdown]
# # Critical mistakes, easy to miss
# I made the mistake of feeding my Phraser the wrong list of sentences earlier. I should have fed it the main training set instead of the test set. It did not form n-grams like "best_total_war" at all, which had negative impact when I first checked the data.
#
# Also, more errors:
#
# I have been training the ngram Phraser on the wrong dataset! I applied it correctly when training the LDA Model, but I didn't replicate it correctly when running the bigram Phraser on subsequent models. It did not combine 'shogun' and 'two' to form 'shogun_two' because I didn't take 'one', 'two', and 'three' out of the first run of stopwords each time.
#
# I will take care of these breaking points because the program can still run, but the analysis will be broken due to an incorrectly trained Phraser.

# %% [markdown]
# # It's not perfect
#
# SpaCy will read some nouns as verbs or other forms of the word, e.g. "map". It appears as a token in an earlier review, but in a later review the word "map" is missing from tokens.
#
# Could be something to improve, but it could require hard-coding it so that it doesn't output this problem again.
